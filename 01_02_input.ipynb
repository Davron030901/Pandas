# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Pandas/blob/main/01_02_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import relevant libraries
import pandas as pd
import numpy as np

# %%
# prompt user for name & store reply in variable
name = input('Please enter your name: ')

# display response to user
print('Nice to meet you,', name)
# Out:
# Please enter your name: Davron
# Nice to meet you, Davron

# %%
# read grades dataset & save as a pandas dataframe
grades = pd.read_csv('grades.csv')

# %%
# display first ten rows of grades
grades.iloc[:10]
# Out:
#    exam  student_id  grade
# 0     1           1   86.0
# 1     1           2   65.0
# 2     1           3   70.0
# 3     1           4   98.0
# 4     1           5   89.0
# 5     1           6    NaN
# 6     1           7   75.0
# 7     1           8   56.0
# 8     1           9   90.0
# 9     1          10   81.0

# %%
# check for missing values in grade column
if grades['grade'].isnull().values.any():
    print('there are missing values')
else:
    print('there are no missing values')
# Out:
# there are missing values

# %%
# fill missing grades with zeros
grades['grade'] = grades['grade'].fillna(0)

# %%
# display first ten rows of grades
grades.iloc[:10]
# Out:
#    exam  student_id  grade
# 0     1           1   86.0
# 1     1           2   65.0
# 2     1           3   70.0
# 3     1           4   98.0
# 4     1           5   89.0
# 5     1           6    0.0
# 6     1           7   75.0
# 7     1           8   56.0
# 8     1           9   90.0
# 9     1          10   81.0

# %%
# compute mean grade for Exam #1 & save in variable
exam_mean=grades.loc[grades['exam']==1]['grade'].mean()
exam_mean
# Out:
# 71.0

# %%
# prompt user for grade & save in variable
grade = input('Please enter your grade for Exam #1: ')

# compute difference from exam1_mean & save in variable
diff = int(grade) - exam_mean

# display response to user based on diff
if (diff > 0):
    print('You scored', diff, 'percent higher than the mean,', exam_mean)
elif (diff < 0):
    print('You scored', diff, 'percent lower than the mean,', exam_mean)
else:
    print('You scored the same as the mean')
# Out:
# Please enter your grade for Exam #1: 71
# You scored the same as the mean
