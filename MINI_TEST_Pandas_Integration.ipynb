# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Pandas/blob/main/MINI_TEST_Pandas_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Employee Department Analysis

# %%
employee_data = {
    'Employee_ID': ['E001', 'E002', 'E003', 'E004', 'E005', 'E006', 'E007', 'E008'],
    'Name': ['Ali', 'Vali', 'Guli', 'Sami', 'Nuri', 'Zara', 'Jasur', 'Madina'],
    'Department': ['IT', 'IT', 'Sales', 'Sales', 'HR', 'HR', 'IT', 'Sales'],
    'Salary': [5000, 5500, 4000, 4500, 3800, 4200, 5200, 4300],
    'Years_Experience': [3, 5, 2, 4, 1, 3, 4, 3],
    'Performance_Score': [85, 92, 78, 88, 75, 82, 90, 85]
}

employee_df = pd.DataFrame(employee_data)
print("Employees data frame:")
print(employee_df)
# Out:
# Employees data frame:
#   Employee_ID    Name Department  Salary  Years_Experience  Performance_Score
# 0        E001     Ali         IT    5000                 3                 85
# 1        E002    Vali         IT    5500                 5                 92
# 2        E003    Guli      Sales    4000                 2                 78
# 3        E004    Sami      Sales    4500                 4                 88
# 4        E005    Nuri         HR    3800                 1                 75
# 5        E006    Zara         HR    4200                 3                 82
# 6        E007   Jasur         IT    5200                 4                 90
# 7        E008  Madina      Sales    4300                 3                 85
