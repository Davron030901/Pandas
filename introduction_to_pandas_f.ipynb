# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Pandas/blob/main/introduction_to_pandas_f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 2 main datatypes python list
series=pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours=pd.Series(["RED","Blue","Green"])
colours
# Out:
# 0      RED
# 1     Blue
# 2    Green
# dtype: object

# %%
# DataFrame = 2-dimensional oython dictionary
car_data=pd.DataFrame({"Car make":series,"Colour":colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    RED
# 1   Toyota   Blue
# 2    Honda  Green

# %%
 # Import data python list axis=0 index, axis=1 data column name
car_sales=pd.read_csv("/content/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe index=False not index copy
car_sales.to_csv("export-car-sales.csv",index=False)

# %%
exported_car_sales = pd.read_csv("export-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Doors"][1]=5
# Out:
# <ipython-input-54-a7616c4d0d0d>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   car_sales["Doors"][1]=5
# <ipython-input-54-a7616c4d0d0d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Doors"][1]=5

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head() #top 5 element
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail() #last 5 element
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
                    index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3] #index parametr
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
# .loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:4]
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-cffc0afb7077> in <cell line: 1>()
# ----> 1 car_sales.Odometer (KM)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %% [markdown]
# #Condition

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  2  1
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(['Make']).sum()
# Out:
#                      Colour  Odometer (KM)  Doors  \
# Make
# BMW                   Black          11179      5
# Honda           RedBlueBlue         188335     13
# Nissan           WhiteWhite         244695      8
# Toyota  WhiteBlueGreenWhite         341805     15
#
#                                        Price
# Make
# BMW                               $22,000.00
# Honda            $5,000.00$7,500.00$7,000.00
# Nissan                    $3,500.00$9,700.00
# Toyota  $4,000.00$7,000.00$4,500.00$6,250.00

# %%
car_sales.groupby("Make")[['Doors','Odometer (KM)']].mean()
# Out:
#            Doors  Odometer (KM)
# Make
# BMW     5.000000   11179.000000
# Honda   4.333333   62778.333333
# Nissan  4.000000  122347.500000
# Toyota  3.750000   85451.250000

# %%
car_sales.groupby("Make")[['Doors','Odometer (KM)']].agg(['sum','mean'])
# Out:
#        Doors           Odometer (KM)
#          sum      mean           sum           mean
# Make
# BMW        5  5.000000         11179   11179.000000
# Honda     13  4.333333        188335   62778.333333
# Nissan     8  4.000000        244695  122347.500000
# Toyota    15  3.750000        341805   85451.250000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-83bf2f29b5a6> in <cell line: 1>()
# ----> 1 car_sales["Price"].plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     497     @final
#     498     def generate(self) -> None:
# --> 499         self._compute_plot_data()
#     500         fig = self.fig
#     501         self._make_plot(fig)
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     696         # no non-numeric frames or series allowed
#     697         if is_empty:
# --> 698             raise TypeError("no numeric data to plot")
#     699
#     700         self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      5   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
dataframe['amount'] = dataframe['amount'].replace('[\$\,\.]', '', regex=True).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-899812044f2e> in <cell line: 1>()
# ----> 1 dataframe['amount'] = dataframe['amount'].replace('[\$\,\.]', '', regex=True).astype(int)
#
# NameError: name 'dataframe' is not defined

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '',regex=True).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      5   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      5   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      5   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      5   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)
# Out:
# <ipython-input-107-950dc6540f18>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    NaN             4.7
# 6   honda   Blue          45698      4   750000    NaN             7.6
# 7   honda   Blue          54738      4   700000    NaN             8.7
# 8  toyota  White          60000      4   625000    NaN             NaN
# 9  nissan  White          31600      4   970000    NaN             NaN
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# 3             1073.184                 4
# 4            18539.265                 4
# 5             4663.011                 4
# 6             3473.048                 4
# 7             4762.206                 4
# 8                  NaN                 4
# 9                  NaN                 4

# %%
car_sales["Seats"].fillna(5, inplace=True)
# Out:
# <ipython-input-127-ecaafdfcb7e4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             NaN
# 9  nissan  White          31600      4   970000    5.0             NaN
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# 3             1073.184                 4
# 4            18539.265                 4
# 5             4663.011                 4
# 6             3473.048                 4
# 7             4762.206                 4
# 8                  NaN                 4
# 9                  NaN                 4

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"]=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# 3             1073.184                 4
# 4            18539.265                 4
# 5             4663.011                 4
# 6             3473.048                 4
# 7             4762.206                 4
# 8                  NaN                 4
# 9                  NaN                 4

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey  Total fuel used
# 0            11253.225                 4                True        11253.225
# 1             8086.708                 4                True         8086.708
# 2             1627.450                 4                True         1627.450
# 3             1073.184                 4                True         1073.184
# 4            18539.265                 4                True        18539.265
# 5             4663.011                 4                True         4663.011
# 6             3473.048                 4                True         3473.048
# 7             4762.206                 4                True         4762.206
# 8             1800.000                 4                True         1800.000
# 9             1422.000                 4                True         1422.000

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey  Total fuel used
# 0            11253.225                 4                True        11253.225
# 1             8086.708                 4                True         8086.708
# 2             1627.450                 4                True         1627.450
# 3             1073.184                 4                True         1073.184
# 4            18539.265                 4                True        18539.265
# 5             4663.011                 4                True         4663.011
# 6             3473.048                 4                True         3473.048
# 7             4762.206                 4                True         4762.206
# 8             1800.000                 4                True         1800.000
# 9             1422.000                 4                True         1422.000

# %%
car_sales["Passed road saftey"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road saftey        bool
# Total fuel used        float64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey  Total fuel used
# 0            11253.225                 4                True        11253.225
# 1             8086.708                 4                True         8086.708
# 2             1627.450                 4                True         1627.450
# 3             1073.184                 4                True         1073.184
# 4            18539.265                 4                True        18539.265
# 5             4663.011                 4                True         4663.011
# 6             3473.048                 4                True         3473.048
# 7             4762.206                 4                True         4762.206
# 8             1800.000                 4                True         1800.000
# 9             1422.000                 4                True         1422.000

# %%
car_sales = car_sales.drop("Total fuel used", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      5   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# 2             1627.450                 4                True
# 3             1073.184                 4                True
# 4            18539.265                 4                True
# 5             4663.011                 4                True
# 6             3473.048                 4                True
# 7             4762.206                 4                True
# 8             1800.000                 4                True
# 9             1422.000                 4                True

# %%
car_sales['Make']=car_sales['Make'].str.upper()

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  TOYOTA   Blue          32549      3   700000    5.0             5.0
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 4  NISSAN  White         213095      4   350000    5.0             8.7
# 1   HONDA    Red          87899      5   500000    5.0             9.2
# 8  TOYOTA  White          60000      4   625000    5.0             3.0
# 0  TOYOTA  White         150043      4   400000    5.0             7.5
# 7   HONDA   Blue          54738      4   700000    5.0             8.7
# 6   HONDA   Blue          45698      4   750000    5.0             7.6
# 5  TOYOTA  Green          99213      4   450000    5.0             4.7
# 9  NISSAN  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 2             1627.450                 4                True
# 3             1073.184                 4                True
# 4            18539.265                 4                True
# 1             8086.708                 4                True
# 8             1800.000                 4                True
# 0            11253.225                 4                True
# 7             4762.206                 4                True
# 6             3473.048                 4                True
# 5             4663.011                 4                True
# 9             1422.000                 4                True

# %%
car_sales.sample(frac=0.5) # random Choose 0.5
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 4  NISSAN  White         213095      4   350000    5.0             8.7
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 0  TOYOTA  White         150043      4   400000    5.0             7.5
# 8  TOYOTA  White          60000      4   625000    5.0             3.0
# 9  NISSAN  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 4            18539.265                 4                True
# 3             1073.184                 4                True
# 0            11253.225                 4                True
# 8             1800.000                 4                True
# 9             1422.000                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  TOYOTA   Blue          32549      3   700000    5.0             5.0
# 5  TOYOTA  Green          99213      4   450000    5.0             4.7
# 1   HONDA    Red          87899      5   500000    5.0             9.2
# 9  NISSAN  White          31600      4   970000    5.0             4.5
# 4  NISSAN  White         213095      4   350000    5.0             8.7
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 6   HONDA   Blue          45698      4   750000    5.0             7.6
# 0  TOYOTA  White         150043      4   400000    5.0             7.5
# 8  TOYOTA  White          60000      4   625000    5.0             3.0
# 7   HONDA   Blue          54738      4   700000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 2             1627.450                 4                True
# 5             4663.011                 4                True
# 1             8086.708                 4                True
# 9             1422.000                 4                True
# 4            18539.265                 4                True
# 3             1073.184                 4                True
# 6             3473.048                 4                True
# 0            11253.225                 4                True
# 8             1800.000                 4                True
# 7             4762.206                 4                True

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 5  TOYOTA  Green          99213      4  450000    5.0             4.7
# 6   HONDA   Blue          45698      4  750000    5.0             7.6
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 5             4663.011                 4                True
# 6             3473.048                 4                True

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  TOYOTA   Blue          32549      3   700000    5.0             5.0
# 5  TOYOTA  Green          99213      4   450000    5.0             4.7
# 1   HONDA    Red          87899      5   500000    5.0             9.2
# 9  NISSAN  White          31600      4   970000    5.0             4.5
# 4  NISSAN  White         213095      4   350000    5.0             8.7
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 6   HONDA   Blue          45698      4   750000    5.0             7.6
# 0  TOYOTA  White         150043      4   400000    5.0             7.5
# 8  TOYOTA  White          60000      4   625000    5.0             3.0
# 7   HONDA   Blue          54738      4   700000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 2             1627.450                 4                True
# 5             4663.011                 4                True
# 1             8086.708                 4                True
# 9             1422.000                 4                True
# 4            18539.265                 4                True
# 3             1073.184                 4                True
# 6             3473.048                 4                True
# 0            11253.225                 4                True
# 8             1800.000                 4                True
# 7             4762.206                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  TOYOTA   Blue          32549      3   700000    5.0             5.0
# 1  TOYOTA  Green          99213      4   450000    5.0             4.7
# 2   HONDA    Red          87899      5   500000    5.0             9.2
# 3  NISSAN  White          31600      4   970000    5.0             4.5
# 4  NISSAN  White         213095      4   350000    5.0             8.7
# 5     BMW  Black          11179      5  2200000    5.0             9.6
# 6   HONDA   Blue          45698      4   750000    5.0             7.6
# 7  TOYOTA  White         150043      4   400000    5.0             7.5
# 8  TOYOTA  White          60000      4   625000    5.0             3.0
# 9   HONDA   Blue          54738      4   700000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0             1627.450                 4                True
# 1             4663.011                 4                True
# 2             8086.708                 4                True
# 3             1422.000                 4                True
# 4            18539.265                 4                True
# 5             1073.184                 4                True
# 6             3473.048                 4                True
# 7            11253.225                 4                True
# 8             1800.000                 4                True
# 9             4762.206                 4                True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# 2             1627.450                 4                True
# 3             1073.184                 4                True
# 4            18539.265                 4                True
# 5             4663.011                 4                True
# 6             3473.048                 4                True
# 7             4762.206                 4                True
# 8             1800.000                 4                True
# 9             1422.000                 4                True

# %%
car_sales["Odometer (Mil)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  TOYOTA  White   58610.546875      4   400000    5.0             7.5
# 1   HONDA    Red   34335.546875      5   500000    5.0             9.2
# 2  TOYOTA   Blue   12714.453125      3   700000    5.0             5.0
# 3     BMW  Black    4366.796875      5  2200000    5.0             9.6
# 4  NISSAN  White   83240.234375      4   350000    5.0             8.7
# 5  TOYOTA  Green   38755.078125      4   450000    5.0             4.7
# 6   HONDA   Blue   17850.781250      4   750000    5.0             7.6
# 7   HONDA   Blue   21382.031250      4   700000    5.0             8.7
# 8  TOYOTA  White   23437.500000      4   625000    5.0             3.0
# 9  NISSAN  White   12343.750000      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey  Odometer (Mil)
# 0            11253.225                 4                True    36631.591797
# 1             8086.708                 4                True    21459.716797
# 2             1627.450                 4                True     7946.533203
# 3             1073.184                 4                True     2729.248047
# 4            18539.265                 4                True    52025.146484
# 5             4663.011                 4                True    24221.923828
# 6             3473.048                 4                True    11156.738281
# 7             4762.206                 4                True    13363.769531
# 8             1800.000                 4                True    14648.437500
# 9             1422.000                 4                True     7714.843750

# %%
# Try it, run your code
# Search for it
# Try again
# Ask

# %% [markdown]
# ## Summary
#
# ### Main topics we covered
# * [Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) - a single column (can be multiple rows) of values.
# * [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html) - multiple columns/rows of values (a DataFrame is comprised of multiple Series).
# * [Importing data](https://pandas.pydata.org/pandas-docs/stable/reference/io.html) - we used [`pd.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html#pandas-read-csv) to read in a CSV (comma-separated values) file but there are multiple options for reading data.
# * [Exporting data](https://pandas.pydata.org/pandas-docs/stable/reference/io.html) - we exported our data using `to_csv()`, however there are multiple methods of exporting data.
# * [Describing data](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
#     * `df.dtypes` - find the datatypes present in a dataframe.
#     * `df.describe()` - find various numerical features of a dataframe.
#     * `df.info()` - find the number of rows and whether or not any of them are empty.
# * [Viewing and selecting data](https://pandas.pydata.org/docs/user_guide/10min.html#viewing-data)
#     * `df.head()` - view the first 5 rows of `df`.
#     * `df.loc` & `df.iloc` - select specific parts of a dataframe.
#     * `df['A']` - select column `A` of `df`.
#     * `df[df['A'] > 1000]` - selection column `A` rows with values over 1000 of `df`.
#     * `df['A']` - plot values from column `A` using matplotlib (defaults to line graph).
# * [Manipulating data and performing operations](https://pandas.pydata.org/docs/user_guide/10min.html#operations) - pandas has many built-in functions you can use to manipulate data, also many of the Python operators (e.g. `+`, `-`, `>`, `==`) work with pandas.
#
# ### Further reading
# Since pandas is such a large library, it would be impossible to cover it all in one go.
#
# The following are some resources you might want to look into for more.
# * [Python for Data Analysis by Wes McKinney](https://wesmckinney.com/book/) - possibly the most complete text of the pandas library (apart from the documentation itself) written by the creator of pandas.
# * [Data Manipulation with Pandas (section of Python Data Science Handbook by Jake VanderPlas)](https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html) - a very hands-on approach to many of the main functions in the pandas library.
#
# ### Exercises
# After completing this notebook, you next thing should be to try out some more pandas code of your own.
#
# I'd suggest at least going through number 1 (write out all the code yourself), a couple from number 2 (again, write out the code yourself) and spend an hour reading number 3 (this is vast but keep it in mind).
#
# 1. [10-minute introduction to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) - go through all the functions here and be sure to write out the code yourself.
# 2. [Pandas getting started tutorial](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/index.html) - pick a couple from here which spark your interest and go through them both writing out the code for your self.
# 3. [Pandas essential basic functionality](https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html) - spend an hour reading this and bookmark it for whenever you need to come back for an overview of pandas.
