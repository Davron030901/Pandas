# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Pandas/blob/main/Missing_Data_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Missing data'ni aniqlash
# NaN qiymatlarni to'ldirish (fillna, interpolate)
# Missing values'ni o'chirish
# NumPy vs Pandas yondashuvlari

# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([1, 2, np.nan, 4, 5])
df = pd.DataFrame({'A': [1, np.nan, 3, None, 5]})

# %%
data = [1, 2, None, 4]

# %% [markdown]
# Aniqlash

# %%
pd.isna(df)
# Out:
#        A
# 0  False
# 1   True
# 2  False
# 3   True
# 4  False

# %%
df.isna()
# Out:
#        A
# 0  False
# 1   True
# 2  False
# 3   True
# 4  False

# %%
np.isnan(arr)
# Out:
# array([False, False,  True, False, False])

# %% [markdown]
# To'ldirish

# %%
df.fillna(0)
# Out:
#      A
# 0  1.0
# 1  0.0
# 2  3.0
# 3  0.0
# 4  5.0

# %%
df.fillna(df.mean())
# Out:
#      A
# 0  1.0
# 1  3.0
# 2  3.0
# 3  3.0
# 4  5.0

# %%
df.fillna(method='ffill')
# Out:
# /tmp/ipykernel_1612/1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#      A
# 0  1.0
# 1  1.0
# 2  3.0
# 3  3.0
# 4  5.0

# %%
df.interpolate()
# Out:
#      A
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  5.0

# %% [markdown]
# O'chirish

# %%
df.dropna()
# Out:
#      A
# 0  1.0
# 2  3.0
# 4  5.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# ```
# NumPy vs Pandas:
#
# NumPy: np.nan, np.isnan(), manual handling
# Pandas: NaN, isna(), auto methods

# %% [markdown]
# #Temperature Data Cleaning (30%)

# %%
temperatures = pd.Series([23.5, np.nan, 25.1, np.nan, 24.8, 26.3, np.nan, 25.9])
count_nan = temperatures.isna().sum()
print(count_nan)
# Out:
# 3
